# %% [markdown]
# <a href="https://colab.research.google.com/github/VemPrava/FMML_Projects_and_Labs/blob/main/Pravallika_Assignment_Module8_of_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-15 04:30:20--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   211MB/s    in 0.3s
#
# 2025-03-15 04:30:22 (211 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 5279    1209.1688v4  The question of aggregating pair-wise comparis...    cs
# 13035  1612.08406v2  The inference of correlated signal fields with...  stat
# 12308  1711.06446v2  Learning representation from relative similari...  stat
# 10466   1210.4883v1  In spectral clustering, one defines a similari...    cs
# 38101  cs/0612033v1  The automatic extraction of acronyms and their...    cs
# ...             ...                                                ...   ...
# 2339    1204.0033v1  Relational data representations have become an...  stat
# 24877   1412.5334v1  The logarithmic model offers new tools for ima...    cs
# 3617   1802.08717v1  Deep learning is a branch of artificial intell...    cs
# 7248   1711.04755v1  Generative Adversarial Networks (GANs) are a p...  stat
# 22448  1607.03574v4  Hierarchical probabilistic models, such as mix...  stat
#
#                                                    title  year  \
# 5279   Rank Centrality: Ranking from Pair-wise Compar...  2012
# 13035  Correlated signal inference by free energy exp...  2016
# 12308  Stochastic Non-convex Ordinal Embedding with S...  2017
# 10466  A Model-Based Approach to Rounding in Spectral...  2012
# 38101  Acronym-Meaning Extraction from Corpora Using ...  2006
# ...                                                  ...   ...
# 2339   Transforming Graph Representations for Statist...  2012
# 24877  The Affine Transforms for Image Enhancement in...  2014
# 3617   Deep learning in radiology: an overview of the...  2018
# 7248     ACtuAL: Actor-Critic Under Adversarial Learning  2017
# 22448  Effects of Additional Data on Bayesian Clustering  2016
#
#                                                 keywords
# 5279   [aggregating, comparisons, collection, trueski...
# 13035  [inference, correlated, correlation, structure...
# 12308  [representation, similarity, comparisons, embe...
# 10466  [clustering, similarity, collection, transform...
# 38101  [automatic, extraction, important, alignment, ...
# ...                                                  ...
# 2339   [relational, representations, increasingly, im...
# 24877  [logarithmic, processing, efficient, enhanceme...
# 3617   [artificial, intelligence, interconnected, alg...
# 7248   [generative, adversarial, framework, generativ...
# 22448  [hierarchical, probabilistic, variables, obser...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 5279     [aggregating, comparisons, collection, trueski...
# 13035    [inference, correlated, correlation, structure...
# 12308    [representation, similarity, comparisons, embe...
# 10466    [clustering, similarity, collection, transform...
# 38101    [automatic, extraction, important, alignment, ...
#                                ...
# 21758    [prediction, formulate, minimization, objectiv...
# 25957    [segmentation, ventricle, resonance, essential...
# 12403    [represent, including, processing, important, ...
# 17373    [similarity, sentences, determine, unrelated, ...
# 14234    [systematic, framework, performing, nonnegativ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8664 words.
# Out of those 4533 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="adc5b73f-558b-47db-b26c-00a934f560a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("adc5b73f-558b-47db-b26c-00a934f560a3")) {                    Plotly.newPlot(                        "adc5b73f-558b-47db-b26c-00a934f560a3",                        [{"x":["intensity","iterative","probability","collection","dependence","transactions","interpretation","associated","stationary","aggregating","preferences","probabilities","particular","obtaining","comparisons","aggregation","centrality","laplacian","discovering","structure","probabilistic","comparison","multinomial","estimated","determines","algorithm","understanding","identical","exploiting","uncertainties","demonstrate","implementations","complexity","analytically","numerical","quantities","mathematical","structures","conceptual","determine","information","challenges","relevance","implementation","introduce","inference","uncertainty","significant","formalism","generated","auxiliary","posterior","exploration","estimates","correlated","performances","correlation","calculable","equations","scientific","applications","simultaneously","marginalization","technological","distributions","strategies","scalability","experiments","following","especially","textitnon","particularly","comparing","stabilized","representation","performance","simulations","effectiveness","introducing","generally","considered","computational","consuming","iterations","optimization","projected","stochastic","attention","decomposition","similarity","embedding","challenge","prediction","conducted","converges","convexity","sometimes","eigenvectors","themselves","subproblems","gracefully","correctly","synthetic","assumption","graphical","contained","clustering","subsequent","partition","transforms","automatic","automatically","alignments","generates","implemented","alternative","additional","transitions","milliseconds","expression","important","algorithms","extraction","different","alignment","extensive","techniques","methodology","splitting","generalizing","structurally","presented","extension","benchmark","demonstrates","regression","detection","supervised","classification","empirically","proposing","artificial","developers","experience","individual","perceptron","principle","accommodating","intuitions","multilayer","recognition","introduces","successful","efficiency","explanatory","empirical","surprising","understand","structural","community","sensitive","treewidth","industrial","conducting","parameter","incorporate","theoretic","mathematically","comprehensive","instances","backbones","combinations","parameters","correlate","heuristics","comparative","backdoors","evaluation","exponentially","lipschitz","identification","competitiveness","unfortunately","properties","optimising","approaches","validation","objective","nonparametric","decoupled","optimisation","inferences","resulting","experimental","membership","interpolation","minimising","constants","limitations","typically"],"y":[31,68,177,79,25,6,50,117,33,19,31,62,277,42,39,25,5,15,24,330,156,135,4,62,9,779,156,15,62,13,578,38,242,14,79,14,49,121,22,83,640,116,41,134,341,205,86,238,13,173,19,38,62,65,25,50,62,0,19,35,417,119,3,7,128,102,34,592,75,95,0,90,85,0,366,908,47,205,56,75,154,279,31,25,277,14,122,165,60,135,110,151,244,59,23,12,24,9,27,12,3,30,129,72,56,23,146,24,22,21,170,189,7,41,109,94,117,9,3,51,340,601,133,733,50,176,385,69,15,16,5,174,81,216,45,130,374,209,529,71,27,123,4,41,103,19,44,0,2,17,377,72,65,159,4,147,8,65,78,71,65,4,17,14,139,59,45,12,46,101,2,46,265,7,49,29,3,231,28,12,102,2,26,185,3,448,60,130,9,3,20,8,149,399,15,15,5,2,57,99],"type":"bar"},{"x":["intensity","iterative","probability","collection","dependence","transactions","in ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4533,), (4533, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.79

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Modeling</span> <span style=''>reverse</span> <span style=''>thinking</span> <span style=''>for</span> <span style=''>machine</span> <span style=''>learning</span> <br/><br/><span style=''>Human</span> <span style=''>inertial</span> <span style=''>thinking</span> <span style=''>schemes</span> <span style=''>can</span> <span style=''>be</span> <span style=''>formed</span> <span style=''>through</span> <span style=''>learning</span> <span style=''>which</span> <span style=''>are</span> <span style=''>then</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>quickly</span> <span style=''>solve</span> <span style=''>similar</span> <span style=''>problems</span> <span style=''>later</span> <span style=''>However</span> <span style=''>when</span> <span style=''>problems</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3117782909930715);'>significantly</span> <span style='background-color:rgba(0, 255, 0, 0.3339399454049136);'>different</span> <span style=''>inertial</span> <span style=''>thinking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generally</span> <span style=''>presents</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>that</span> <span style=''>are</span> <span style=''>definitely</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>imperfect</span> <span style=''>In</span> <span style=''>such</span> <span style=''>cases</span> <span style=''>people</span> <span style=''>will</span> <span style=''>apply</span> <span style=''>creative</span> <span style=''>thinking</span> <span style=''>such</span> <span style=''>as</span> <span style=''>reverse</span> <span style=''>thinking</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>problems</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Similarly</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>also</span> <span style=''>form</span> <span style=''>inertial</span> <span style=''>thinking</span> <span style=''>schemes</span> <span style=''>through</span> <span style=''>learning</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.33858267716535423);'>knowledge</span> <span style=''>from</span> <span style=''>a</span> <span style=''>large</span> <span style=''>amount</span> <span style=''>of</span> <span style=''>data</span> <span style=''>However</span> <span style=''>when</span> <span style=''>the</span> <span style=''>testing</span> <span style=''>data</span> <span style=''>are</span> <span style=''>vastly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difference</span> <span style=''>the</span> <span style=''>formed</span> <span style=''>inertial</span> <span style=''>thinking</span> <span style=''>schemes</span> <span style=''>will</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>inevitably</span> <span style=''>generate</span> <span style=''>errors</span> <span style=''>This</span> <span style=''>kind</span> <span style=''>of</span> <span style=''>inertial</span> <span style=''>thinking</span> <span style=''>is</span> <span style=''>called</span> <span style=''>illusion</span> <span style=''>inertial</span> <span style=''>thinking</span> <span style=''>Because</span> <span style=''>all</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>do</span> <span style=''>not</span> <span style=''>consider</span> <span style=''>illusion</span> <span style=''>inertial</span> <span style=''>thinking</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>that</span> <span style=''>uses</span> <span style=''>reverse</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Generalization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Properties</span> <span style=''>of</span> <span style=''>Doubly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>Learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithms</span> <br/><br/><span style=''>Doubly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style=''>scalable</span> <span style=''>kernel</span> <span style=''>methods</span> <span style=''>that</span> <span style=''>perform</span> <span style=''>very</span> <span style=''>well</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>However</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>are</span> <span style=''>not</span> <span style=''>well</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understood</span> <span style=''>and</span> <span style=''>their</span> <span style=''>analysis</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>since</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>learning</span> <span style=''>sequence</span> <span style=''>may</span> <span style=''>not</span> <span style=''>be</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>space</span> <span style=''>induced</span> <span style=''>by</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>an</span> <span style=''>in</span> <span style=''>depth</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>analysis</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>variants</span> <span style=''>of</span> <span style=''>doubly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>within</span> <span style=''>the</span> <span style=''>setting</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reproducing</span> <span style=''>kernel</span> <span style=''>Hilbert</span> <span style=''>space</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considering</span> <span style=''>the</span> <span style=''>square</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Particularly</span> <span style=''>we</span> <span style=''>derive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>results</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>error</span> <span style=''>for</span> <span style=''>the</span> <span style=''>studied</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>either</span> <span style=''>with</span> <span style=''>or</span> <span style=''>without</span> <span style=''>an</span> <span style=''>explicit</span> <span style=''>penalty</span> <span style=''>term</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>Initializations</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.32944606413994165);'>Convergence</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Nonnegative</span> <span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3739130434782609);'>Factorization</span> <br/><br/><span style=''>It</span> <span style=''>is</span> <span style=''>well</span> <span style=''>known</span> <span style=''>that</span> <span style=''>good</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>initializations</span> <span style=''>can</span> <span style=''>improve</span> <span style=''>the</span> <span style=''>speed</span> <span style=''>and</span> <span style=''>accuracy</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>of</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>nonnegative</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3739130434782609);'>factorization</span> <span style=''>(NMF)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>Many</span> <span style=''>NMF</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitive</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initialization</span> <span style=''>of</span> <span style=''>W</span> <span style=''>or</span> <span style=''>H</span> <span style=''>or</span> <span style=''>both</span> <span style=''>This</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>especially</span> <span style=''>true</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternating</span> <span style=''>least</span> <span style=''>squares</span> <span style=''>(ALS)</span> <span style=''>type</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>the</span> <span style=''>two</span> <span style=''>new</span> <span style=''>ALS</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style=''>we</span> <span style=''>present</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>We</span> <span style=''>compare</span> <span style=''>the</span> <span style=''>results</span> <span style=''>of</span> <span style=''>six</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initialization</span> <span style='background-color:rgba(255, 0, 0, 0.3191489361702127);'>procedures</span> <span style=''>(two</span> <span style=''>standard</span> <span style=''>and</span> <span style=''>four</span> <span style=''>new)</span> <span style=''>on</span> <span style=''>our</span> <span style=''>ALS</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>Lastly</span> <span style=''>we</span> <span style=''>discuss</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>issue</span> <span style=''>of</span> <span style=''>choosing</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>appropriate</span> <span style='background-color:rgba(255, 0, 0, 0.32944606413994165);'>convergence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Accurate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimators</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Improving</span> <span style=''>Minwise</span> <span style=''>Hashing</span> <span style=''>and</span> <span style=''>b</span> <span style=''>Bit</span> <span style=''>Minwise</span> <span style=''>Hashing</span> <br/><br/><span style=''>Minwise</span> <span style=''>hashing</span> <span style=''>is</span> <span style=''>the</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>search</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>databases</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>set</span> <span style=''>(eg</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>01</span> <span style=''>vector)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarities</span> <span style=''>Recently</span> <span style=''>b</span> <span style=''>bit</span> <span style=''>minwise</span> <span style=''>hashing</span> <span style=''>was</span> <span style=''>proposed</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>improves</span> <span style=''>upon</span> <span style=''>the</span> <span style=''>original</span> <span style=''>minwise</span> <span style=''>hashing</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>by</span> <span style=''>storing</span> <span style=''>only</span> <span style=''>the</span> <span style=''>lowest</span> <span style=''>b</span> <span style=''>bits</span> <span style=''>of</span> <span style=''>each</span> <span style=''>hashed</span> <span style=''>value</span> <span style=''>as</span> <span style=''>opposed</span> <span style=''>to</span> <span style=''>using</span> <span style=''>64</span> <span style=''>bits</span> <span style=''>b</span> <span style=''>bit</span> <span style=''>hashing</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particularly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>which</span> <span style=''>mainly</span> <span style=''>concern</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarities</span> <span style=''>(eg</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resemblance</span> <span style=''>05)</span> <span style=''>However</span> <span style=''>there</span> <span style=''>are</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>in</span> <span style=''>which</span> <span style=''>not</span> <span style=''>just</span> <span style=''>pairs</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarities</span> <span style=''>matter</span> <span style=''>For</span> <span style=''>example</span> <span style=''>many</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>require</span> <span style=''>all</span> <span style=''>pairwise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarities</span> <span style=''>and</span> <span style=''>it</span> <span style=''>is</span> <span style=''>exp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.09006763972944108)
# 	architecture (0.07831968672125311)
# 	processing (0.09861160555357779)
# 	representation (0.13029547881808473)
# 	segmentation (0.06870772516909933)
# 	experimental (0.1420434318262727)
# 	different (0.2609469562121752)
# 	detection (0.13314346742613029)
# 	recognition (0.1342114631541474)
# 	convolutional (0.1327874688501246)
#
# Some Statistics words are:
# 	optimization (0.1903566047212456)
# 	theoretical (0.14665996986438976)
# 	variables (0.14314414866901054)
# 	estimation (0.17528879959819185)
# 	statistical (0.16122551481667505)
# 	distribution (0.18935208437970869)
# 	algorithm (0.3902561526870919)
# 	inference (0.19688598694123555)
# 	dimensional (0.18884982420894023)
# 	regression (0.19337016574585636)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="809f18c1-b1f4-47c6-a933-1a14e4ce8d88" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("809f18c1-b1f4-47c6-a933-1a14e4ce8d88")) {                    Plotly.newPlot(                        "809f18c1-b1f4-47c6-a933-1a14e4ce8d88",                        [{"x":["intensity","iterative","probability","collection","dependence","transactions","interpretation","associated","stationary","aggregating","preferences","probabilities","particular","obtaining","comparisons","aggregation","centrality","laplacian","discovering","structure","probabilistic","comparison","multinomial","estimated","determines","algorithm","understanding","identical","exploiting","uncertainties","demonstrate","implementations","complexity","analytically","numerical","quantities","mathematical","structures","conceptual","determine","information","challenges","relevance","implementation","introduce","inference","uncertainty","significant","formalism","generated","auxiliary","posterior","exploration","estimates","correlated","performances","correlation","calculable","equations","scientific","applications","simultaneously","marginalization","technological","distributions","strategies","scalability","experiments","following","especially","textitnon","particularly","comparing","stabilized","representation","performance","simulations","effectiveness","introducing","generally","considered","computational","consuming","iterations","optimization","projected","stochastic","attention","decomposition","similarity","embedding","challenge","prediction","conducted","converges","convexity","sometimes","eigenvectors","themselves","subproblems","gracefully","correctly","synthetic","assumption","graphical","contained","clustering","subsequent","partition","transforms","automatic","automatically","alignments","generates","implemented","alternative","additional","transitions","milliseconds","expression","important","algorithms","extraction","different","alignment","extensive","techniques","methodology","splitting","generalizing","structurally","presented","extension","benchmark","demonstrates","regression","detection","supervised","classification","empirically","proposing","artificial","developers","experience","individual","perceptron","principle","accommodating","intuitions","multilayer","recognition","introduces","successful","efficiency","explanatory","empirical","surprising","understand","structural","community","sensitive","treewidth","industrial","conducting","parameter","incorporate","theoretic","mathematically","comprehensive","instances","backbones","combinations","parameters","correlate","heuristics","comparative","backdoors","evaluation","exponentially","lipschitz","identification","competitiveness","unfortunately","properties","optimising","approaches","validation","objective","nonparametric","decoupled","optimisation","inferences","resulting","experimental","membership","interpolation","minimising","constants","limitations","typically","furthermore","numerically","nonlinear","unobserved","knowledge","monolingual","communicate","motivated","outperform","switching","phenomenon","difficult","reduction","dictionary","translation","sentiment","meaningful","authority","establish","recognizers","representations","processing","languages","recurrent","resources","matchings","introduction","illustrate","specified","application","advantage","investigated","potential","naturally","according","flexibility","cardinality","consideration","efficient","criterion","extensions","egalitarian","unacceptable","programming","straightforwardly","individuals","projection","implications","intrinsic","statistical","dimension","motivation","quantization","combination","dimensional","environments ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	calculable
# 	textitnon
# 	stabilized
# 	accommodating
# 	blockmodels
# 	minibatches
# 	procrustes
# 	individualized
# 	underscore
# 	covariances
# 	breakdown
# 	retrospectively
# 	blackwellized
# 	tibshirani
# 	robustification
# 	hypernetwork
# 	homoscedastic
# 	conservative
# 	encountering
# 	consonants
# Some words which never appear in Statistics papers:
# 	milliseconds
# 	backbones
# 	backdoors
# 	egalitarian
# 	unacceptable
# 	connectionist
# 	intensional
# 	happiness
# 	personalities
# 	declarative
# 	syntactic
# 	biometrics
# 	possibilistic
# 	achievability
# 	recalling
# 	mammograms
# 	mammographic
# 	radiologist
# 	finetuning
# 	geolocation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0653220120773686e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7416666666666667

# %% [markdown]
# The Naive Bayes classifier is based on Bayes' theorem, which calculates the probability of a hypothesis (in this case, the category of a paper) based on prior knowledge and new evidence. It assumes that the features (keywords) are conditionally independent, which makes the computation simpler even though it’s often not entirely true in real-world scenarios. Despite this strong assumption, Naive Bayes tends to perform well in text classification because the independence assumption reduces the complexity of the model and prevents overfitting. The classifier calculates three key components: prior probability (the likelihood of a paper belonging to a category before seeing any data), likelihood (the probability of observing certain keywords given the category), and evidence (the overall probability of observing the data). Smoothing techniques like Laplace smoothing are applied to handle cases where certain words are missing from the training data, which helps avoid zero probabilities. While the model is relatively simple compared to other machine learning approaches, its strength lies in its ability to handle large text datasets efficiently and provide interpretable results. The ability to highlight which words influenced a prediction makes it easier to understand the model’s behavior, adding to its practical value despite the independence assumption not holding perfectly.
